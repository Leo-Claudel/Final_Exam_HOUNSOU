# %%
# PART 2
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
df = pd.read_csv(r'C:\Users\CLAUDEL HOUNSOU\OneDrive\Documents\Python\HOUNSOU Ifede Leonid Claudel.csv')

# %%
df
# Out:
#                         Company Ticker Market value as of 31 December, 2023  \
# 0               APPLE INC (COM)   AAPL                   174,347,467,000.00
# 1    BANK OF AMERICA CORP (COM)    BAC                    34,776,127,000.00
# 2     AMERICAN EXPRESS CO (COM)    AXP                    28,402,748,000.00
# 3            COCA COLA CO (COM)     KO                    23,571,999,000.00
# 4            CHEVRON CORP (COM)    CVX                    18,808,080,000.00
# ..                          ...    ...                                  ...
# 992                         NaN    NaN                                  NaN
# 993                         NaN    NaN                                  NaN
# 994                         NaN    NaN                                  NaN
# 995                         NaN    NaN                                  NaN
# 996                         NaN    NaN                                  NaN
#
# ...

# %%
# Display the first few rows of the dataset
df.head()
# Out:
#                       Company Ticker Market value as of 31 December, 2023  \
# 0             APPLE INC (COM)   AAPL                   174,347,467,000.00
# 1  BANK OF AMERICA CORP (COM)    BAC                    34,776,127,000.00
# 2   AMERICAN EXPRESS CO (COM)    AXP                    28,402,748,000.00
# 3          COCA COLA CO (COM)     KO                    23,571,999,000.00
# 4          CHEVRON CORP (COM)    CVX                    18,808,080,000.00
#
#    Number of shares % of total portfolio   Domain  Score
# 0    905,560,000.00               50.19%   health   17.0
# 1  1,032,852,006.00               10.01%   drinks   28.0
# 2    151,610,700.00                8.18%  finance   19.0
# 3    400,000,000.00                6.79%     food   22.0
# 4    126,093,326.00                5.41%  tech:it   37.0

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Company                                 956
# Ticker                                  956
# Market value as of 31 December, 2023    956
# Number of shares                        956
# % of total portfolio                    956
# Domain                                  956
# Score                                   956
# dtype: int64

# %%
# Summary statistics
df.describe()

# From this basic statistical analysis we see that 25% of the companies score less than or equal to 22 while 75% 
# of them score less than or equal to 43. The score ranges from 12 to 75.
# Out:
#            Score
# count  41.000000
# mean   37.463415
# std    15.026805
# min    12.000000
# 25%    22.000000
# 50%    42.000000
# 75%    43.000000
# max    74.000000

# %%
# Visualizations
plt.figure(figsize=(10, 6))
sns.histplot(df['column_name'], bins=30)  # Replace 'column_name' with your actual column
plt.title('Distribution of Column Name')
plt.show()

# %%
# Data Overview : Here we are going tocheck the structure of the data, including its shape, data types, and any missing values.

# The shape of the dataset
df.shape
# Out:
# (997, 7)

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Company                                 956
# Ticker                                  956
# Market value as of 31 December, 2023    956
# Number of shares                        956
# % of total portfolio                    956
# Domain                                  956
# Score                                   956
# dtype: int64

# %%
# Step 3: Data Cleaning: Here we will clean the data by converting relevant columns to appropriate data types and handling any inconsistencies.
# Remove commas from numeric columns and convert to float
df['Market value as of 31 December, 2023'] = df['Market value as of 31 December, 2023'].replace(',', '', regex=True).astype(float)
df['Number of shares'] = df['Number of shares'].replace(',', '', regex=True).astype(float)

# %%
# Display cleaned data types
print("Cleaned data types:\n", df.dtypes)
# Out:
# Cleaned data types:
#  Company                                  object
# Ticker                                   object
# Market value as of 31 December, 2023    float64
# Number of shares                        float64
# % of total portfolio                    float64
# Domain                                   object
# Score                                   float64
# dtype: object

# %%
# Step 4: Exploratory Data Analysis (EDA): We will analyze the data and extract insights.

# Get top 10 companies by market value
top_companies = df.nlargest(10, 'Market value as of 31 December, 2023')

# %%
top_companies
# Out:
#                               Company Ticker  \
# 0                     APPLE INC (COM)   AAPL
# 1          BANK OF AMERICA CORP (COM)    BAC
# 2           AMERICAN EXPRESS CO (COM)    AXP
# 3                  COCA COLA CO (COM)     KO
# 4                  CHEVRON CORP (COM)    CVX
# 5          OCCIDENTAL PETROLEUM (COM)    OXY
# 6                KRAFT HEINZ CO (COM)    KHC
# 7                   MOODYS CORP (COM)    MCO
# 8  DAVITA HEALTHCARE PARTNERS I (COM)    DVA
# 9                CITIGROUP INC. (COM)      C
#
#    Market value as of 31 December, 2023  Number of shares  \
# 0                          1.743475e+11      9.055600e+08
# 1                          3.477613e+10      1.032852e+09
# 2                          2.840275e+10      1.516107e+08
# 3                          2.357200e+10      4.000000e+08
# 4                          1.880808e+10      1.260933e+08
# 5                          1.455227e+10      2.437158e+08
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x='Market value as of 31 December, 2023', y='Company', data=top_companies, palette='viridis')
plt.title('Top 10 Companies by Market Value')
plt.xlabel('Market Value (in billions)')
plt.ylabel('Company')
plt.show() 

# Top Companies: This bar chart shows the top 10 companies by market value, highlighting which ones dominate the market.
# Out:
# C:\Users\CLAUDEL HOUNSOU\AppData\Local\Temp\ipykernel_24400\1458670621.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Market value as of 31 December, 2023', y='Company', data=top_companies, palette='viridis')

# %%
# Insight 2: Portfolio Distribution
# Visualization of portfolio distribution
plt.figure(figsize=(10, 6))
sns.histplot(df['% of total portfolio'], bins=20, kde=True, color='blue')
plt.title('Distribution of % of Total Portfolio')
plt.xlabel('% of Total Portfolio')
plt.ylabel('Frequency')
plt.show()

# Portfolio Distribution: We have here an illustration of the distribution of the percentage of the total portfolio, indicating how the investments are diversified .

# %%
# Insight 3: Market Value vs. Number of Shares
# Scatter plot of Market Value vs. Number of Shares
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Number of shares', y='Market value as of 31 December, 2023', data=df, hue='Domain', palette='Set2')
plt.title('Market Value vs. Number of Shares')
plt.xlabel('Number of Shares')
plt.ylabel('Market Value')
plt.xscale('log')  # Log scale for better visualization
plt.yscale('log')  # Log scale for better visualization
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# Market Value vs. Shares: This scatter plot reveals the relationship between the number of shares and market value, categorized by domain.

# %%
# Insight 4: Average Score by Domain
# Calculate average score by domain
avg_score_by_domain = df.groupby('Domain')['Score'].mean().reset_index()

# Visualization
plt.figure(figsize=(10, 6))
sns.barplot(x='Score', y='Domain', data=avg_score_by_domain, palette='coolwarm')
plt.title('Average Score by Domain')
plt.xlabel('Average Score')
plt.ylabel('Domain')
plt.show()

# Average Score by Domain: This bar chart provides insight into the average score by domain, indicating the performance across different sectors.
# Out:
# C:\Users\CLAUDEL HOUNSOU\AppData\Local\Temp\ipykernel_24400\2886707996.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Score', y='Domain', data=avg_score_by_domain, palette='coolwarm')

# %%
# Insight 5: Correlation Heatmap
# Correlation heatmap
plt.figure(figsize=(10, 8))
correlation_matrix = df[['Market value as of 31 December, 2023', 'Number of shares', '% of total portfolio', 'Score']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# Correlation Analysis: This heatmap shows the correlations between key numerical variables, helping to identify relationships within the data.

# %%
# In conclusion, this EDA has provided valuable insights into the dataset, revealing trends and relationships that could inform investment decisions. 
# Further analysis could include predictive modeling or deeper dives into specific domains or companies.
